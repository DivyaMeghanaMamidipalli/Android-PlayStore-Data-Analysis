# %%
apps=['org.khanacademy.android','com.duolingo','in.gov.diksha.app','com.byjus.thelearningapp','org.khankids.android','com.udemy.android','com.Extramarks.Smartstudy','com.vedantu.app','com.yyinedu.pigeon','in.gov.epathshala','com.eduauraa.eduauraaapp','haygot.togyah.app','org.coursera.android','com.teachmint.teachmint','com.soniqmantra.kutuki','com.unacademyapp','com.getepic.Epic','com.rvappstudios.math.kids.counting','co.brainly','mobi.abcmouse.academy_goo','com.ulesson','org.edx.mobile','com.prodigygame.prodigy','com.memrise.android.memrisecompanion','com.embibe.student','com.thirdflix.practically','com.rvappstudios.abc_kids_toddler_tracing_phonics','tinytap.kids.learning.games','com.lms.greatlakes','com.doubtnutapp']

# %% [markdown]
# ##Scrapper

# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import Sort, reviews_all, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.duolingo',
    lang='en',                # defaults to 'en'
    country='in',             # defaults to 'us'
    sort=Sort.MOST_RELEVANT,  # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1000,               # defaults to 100
    filter_score_with=None
         # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
scrapeddata = pd.DataFrame(np.array(result),columns=['review'])

scrapeddata = scrapeddata.join(pd.DataFrame(scrapeddata.pop('review').tolist()))

scrapeddata.head()
# Out:
#                                reviewId         userName  \
# 0  08cb217b-435a-4528-8e9c-6549be647ccf  Siddharth Gupta
# 1  1dd8abcf-a296-45ff-b4e9-a06f8dc76a5d     shiny hannah
# 2  145f8634-9327-40ce-b033-b617763bfcd8    Ashray Adappa
# 3  cbc24d89-76fb-4ed2-99bc-5a7cfb59f75f   Don Chatterjee
# 4  81739d17-d53b-455a-8ccb-f09e560168f6     Anika Tahsin
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a/AItbvm...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0  Learn a new language with fun! I've been using...      5           1074
# 1  Duolingo has done wonders in my language skill...      4           1082
# ...

# %%
len(scrapeddata.index)
# Out:
# 1000

# %%
scrapeddata[['content','score','thumbsUpCount']].head()
# Out:
#                                              content  score  thumbsUpCount
# 0  Learn a new language with fun! I've been using...      5           1074
# 1  Duolingo has done wonders in my language skill...      4           1082
# 2  One of the best language learning apps ever ma...      5           1146
# 3  Extremely convenient, effective and interestin...      5            147
# 4  I've been using this application for more than...      5            530

# %%
scrappeddata1 = scrapeddata[['content','score','thumbsUpCount']]
sorteddata = scrappeddata1.sort_values(by='thumbsUpCount', ascending=False) #Sort by Newest, change to True if you want to sort by Oldest.
sorteddata.head()
# Out:
#                                                content  score  thumbsUpCount
# 2    One of the best language learning apps ever ma...      5           1146
# 1    Duolingo has done wonders in my language skill...      4           1082
# 0    Learn a new language with fun! I've been using...      5           1074
# 425  I am happy with the app and have been learning...      4            574
# 4    I've been using this application for more than...      5            530

# %%
sorteddata.to_excel("Duolingo.xlsx", index = False)

# %%
sorteddata.to_csv("Duolingo.csv", index = False)
